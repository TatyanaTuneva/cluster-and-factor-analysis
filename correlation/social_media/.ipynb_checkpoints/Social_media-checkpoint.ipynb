# %%
import pandas as pd

# %%
data = pd.read_csv('social_media-RU-monthly-201801-201812.csv')
data = pd.merge(data, pd.read_csv('social_media-RU-monthly-201901-201912.csv'), how='outer', on=['Date'])

# %%
data
# Out:
#        Date  VKontakte_x  YouTube_x  Facebook_x  Twitter_x  Pinterest_x  \
# 0   2018-01        24.88      23.25       21.38      15.85         6.71
# 1   2018-02        18.18      27.41       16.88      24.76         5.89
# 2   2018-03        21.34      28.85       22.04       9.60         7.42
# 3   2018-04        30.75      18.48       23.91      10.63         7.72
# 4   2018-05        29.85      24.34       21.70      12.85         5.67
# 5   2018-06        19.66      26.75       25.83      13.96         7.13
# 6   2018-07        20.25      25.40       24.80      16.55         5.13
# 7   2018-08        19.58      22.85       20.92      12.99         6.34
# 8   2018-09        19.84      19.19       19.59      11.42         6.89
# 9   2018-10        25.37      19.75       21.99      13.02         6.37
# 10  2018-11        22.81      14.07       29.78      10.10         8.56
# 11  2018-12        20.57       9.90       22.17      25.77         9.82
# ...
